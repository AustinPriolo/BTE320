# %% [markdown]
# <a href="https://colab.research.google.com/github/AustinPriolo/BTE320/blob/main/In_class_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sales = float(input("Enter Sales ($): "))
rate = float(input("Enter Tax Rate (%): "))

cogs = sales * 0.4
gross_profit = sales - cogs
taxes = rate * gross_profit
net = gross_profit - taxes

print(f"Sales: {sales}$")
print(f"Cost of Goods Sold: {cogs}$")
print(f"Gross Profit: {gross_profit}$")
print(f"Taxes: {taxes}$")
print(f"Net Income: {net}$")
# Out:
# Enter Sales ($): 12000
# Enter Tax Rate (%): 0.3
# Sales: 12000.0$
# Cost of Goods Sold: 4800.0$
# Gross Profit: 7200.0$
# Taxes: 2160.0$
# Net Income: 5040.0$

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
op = input("Choose numerical operator: ")

if op == "+":
    res = num1 + num2
elif op == "-":
    res = num1 - num2
elif op == "*":
    res = num1 * num2
elif op == "/":
    res = num1 / num2
elif op == "//":
    res = num1 // num2
elif op == "**":
    res = num1 ** num2
elif op == "%":
    res = num1 % num2
else:
    print("Invalid operation")
    res = None

print(f"Result: {res}")

# %%
for hour in range(1, 9):
    fee = 5 + 2.5 * hour
    if fee < 10:
        fee = 10.0
    elif fee > 20:
        fee = 20.0
    print(hour, fee)
# Out:
# 1 10.0
# 2 10.0
# 3 12.5
# 4 15.0
# 5 17.5
# 6 20.0
# 7 20.0
# 8 20.0

# %%
ticket = 20
init_attendees = 20
fixed_cost = 200

for ad in range (0, 201,25):
    revenue = (init_attendees + 2 * round(ad ** 0.5)) * 10
    costs = fixed_cost + ad
    profit = revenue - costs
    print(ad, profit)
# Out:
# 0 0
# 25 75
# 50 90
# 75 105
# 100 100
# 125 95
# 150 90
# 175 85
# 200 80

# %%
hour = 1
while hour < 9:
    fee = 5 + 2.5 * hour
    if fee < 10:
        fee = 10.0
    elif fee > 20:
        fee = 20.0

    print(hour, fee)
    hour += 1
# Out:
# 1 10.0
# 2 10.0
# 3 12.5
# 4 15.0
# 5 17.5
# 6 20.0
# 7 20.0
# 8 20.0

# %%
import math

ticket = 20
init_attendees = 20
fixed_cost = 200

ad = 0
while ad < 201:
    revenue = (init_attendees + 2 * round(math.sqrt(ad))) * 10
    costs = fixed_cost + ad
    profit = revenue - costs
    print(ad, profit)
    ad += 25
# Out:
# 0 0
# 25 75
# 50 90
# 75 105
# 100 100
# 125 95
# 150 90
# 175 85
# 200 80

# %%
import random

play = input("Do you want to play? (y/n): ").lower()

while play == "y":
    p_move = input("Choose between rock, paper, scissors: ").lower()
    c_move = random.choice(['rock', 'paper', 'scissors'])

    print(f"Player move: {p_move}")
    print(f"Computer move: {c_move}")

    if p_move == c_move:
        print("Draw")
    elif ((p_move == "rock" and c_move == "scissors") or
          (p_move == "scissors" and c_move == "paper") or
          (p_move == "paper" and c_move == "rock")):
        print("Player wins!")
    else:
        print("Computer wins!")

    play = input("Do you want to play again? (y/n): ").lower()
# Out:
# Do you want to play? (y/n): y
# Choose between rock, paper, scissors: rock
# Player move: rock
# Computer move: paper
# Computer wins!
# Do you want to play again? (y/n): y
# Choose between rock, paper, scissors: scissors
# Player move: scissors
# Computer move: rock
# Computer wins!
# Do you want to play again? (y/n): n
